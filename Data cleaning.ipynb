# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/jarsmp37/introds/main/Churn_Bank.csv'
df=pd.read_csv(url)
df.head(5)
# Out:
#   RowNumber  CustomerId   Surname CreditScore Geography  Gender   Age Tenure  \
# 0       1.0  15634602.0  Hargrave         619    France  Female   NaN      2
# 1       2.0  15647311.0      Hill         608     Spain  Female  41.0      1
# 2       3.0  15619304.0      Onio         502    France  Female  42.0      8
# 3       4.0  15701354.0      Boni         699    France  Female  39.0      1
# 4       5.0  15737888.0  Mitchell         850     Spain  Female   NaN      2
#
#      Balance NumOfProducts HasCrCard IsActiveMember EstimatedSalary Exited  \
# 0        0.0           1.0         1              1       101348.88      1
# 1   83807.86           1.0         0              1       112542.58      0
# 2   159660.8           3.0         1              0       113931.57    NaN
# 3        0.0           2.0         0              0        93826.63      0
# 4  125510.82           1.0         1              1   invalid_value      0
#
# ...

# %%
df.shape
# Out:
# (12205, 18)

# %%
#Dice el tipo de dato
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12205 entries, 0 to 12204
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           12069 non-null  object
#  1   CustomerId          12050 non-null  object
#  2   Surname             12083 non-null  object
#  3   CreditScore         12080 non-null  object
#  4   Geography           12076 non-null  object
#  5   Gender              12069 non-null  object
#  6   Age                 12057 non-null  object
#  7   Tenure              12079 non-null  object
#  8   Balance             12065 non-null  object
#  9   NumOfProducts       12085 non-null  object
#  10  HasCrCard           12052 non-null  object
#  11  IsActiveMember      12076 non-null  object
#  12  EstimatedSalary     12061 non-null  object
#  13  Exited              12065 non-null  object
#  14  Complain            12060 non-null  object
# ...

# %%
#Saca datos estadisticos
df.describe()
# Out:
#             RowNumber     CustomerId        Surname CreditScore Geography  \
# count           12069          12050          12083       12080     12076
# unique           9778           9756           2902         461         4
# top     invalid_value  invalid_value  invalid_value         850    France
# freq              134            140            123         276      6004
#
#        Gender    Age Tenure Balance NumOfProducts HasCrCard IsActiveMember  \
# count   12069  12057  12079   12065         12085     12052          12076
# unique      3     71     12    6235             5         3              3
# top      Male   38.0      2     0.0           1.0         1              1
# freq     6526    571   1239    4300          6048      8431           6159
#
#        EstimatedSalary Exited Complain Satisfaction Score Card Type  \
# count            12061  12065    12060              12060     12036
# unique            9754      3        3                  6         5
# ...

# %%
#Cuantos valores hay nulos
df.isnull().sum()
# Out:
# RowNumber             136
# CustomerId            155
# Surname               122
# CreditScore           125
# Geography             129
# Gender                136
# Age                   148
# Tenure                126
# Balance               140
# NumOfProducts         120
# HasCrCard             153
# IsActiveMember        129
# EstimatedSalary       144
# Exited                140
# Complain              145
# Satisfaction Score    145
# Card Type             169
# Point Earned          126
# dtype: int64

# %%
#Dice si el valor esta vacio
df.isnull()
# Out:
#        RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0          False       False    False        False      False   False   True
# 1          False       False    False        False      False   False  False
# 2          False       False    False        False      False   False  False
# 3          False       False    False        False      False   False  False
# 4          False       False    False        False      False   False   True
# ...          ...         ...      ...          ...        ...     ...    ...
# 12200      False       False    False        False      False   False  False
# 12201      False       False    False        False      False   False  False
# 12202      False       False    False        False      False   False  False
# 12203      False       False    False        False      False   False  False
# 12204      False       False    False        False      False   False  False
#
# ...

# %%
#Vista de db sin valor nulos
df.dropna()
# Out:
#       RowNumber  CustomerId   Surname CreditScore      Geography  Gender  \
# 1           2.0  15647311.0      Hill         608          Spain  Female
# 3           4.0  15701354.0      Boni         699         France  Female
# 5           6.0  15574012.0       Chu         645          Spain    Male
# 6           7.0  15592531.0  Bartlett         822         France    Male
# 7           8.0  15656148.0    Obinna         376        Germany  Female
# ...         ...         ...       ...         ...            ...     ...
# 12199    2271.0  15622217.0        Tu         538         France  Female
# 12201    1272.0  15793854.0     Ahmed         723         France    Male
# 12202    4942.0  15715047.0    Joshua         640  invalid_value    Male
# 12203    8299.0  15605534.0  Turnbull         644        Germany  Female
# 12204    1689.0  15804610.0    Valdez         601         France  Female
#
#         Age Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %%
#Elimina todos los nulos y guarda los cambios
df_without_nulls=df.dropna()
df_without_nulls
# Out:
#       RowNumber  CustomerId   Surname CreditScore      Geography  Gender  \
# 1           2.0  15647311.0      Hill         608          Spain  Female
# 3           4.0  15701354.0      Boni         699         France  Female
# 5           6.0  15574012.0       Chu         645          Spain    Male
# 6           7.0  15592531.0  Bartlett         822         France    Male
# 7           8.0  15656148.0    Obinna         376        Germany  Female
# ...         ...         ...       ...         ...            ...     ...
# 12199    2271.0  15622217.0        Tu         538         France  Female
# 12201    1272.0  15793854.0     Ahmed         723         France    Male
# 12202    4942.0  15715047.0    Joshua         640  invalid_value    Male
# 12203    8299.0  15605534.0  Turnbull         644        Germany  Female
# 12204    1689.0  15804610.0    Valdez         601         France  Female
#
#         Age Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %%
#Tabla booleana para los duplicados
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12200     True
# 12201     True
# 12202     True
# 12203     True
# 12204     True
# Length: 12205, dtype: bool

# %%
#Suma los duplicados
df.duplicated().sum()
# Out:
# np.int64(1814)

# %%
df_without_nulls.duplicated().sum()
# Out:
# np.int64(1616)

# %%
#Elimina los duplicados
df_without_nulls_and_duplicates = df_without_nulls.drop_duplicates()
df_without_nulls_and_duplicates
# Out:
#       RowNumber  CustomerId    Surname CreditScore Geography  Gender   Age  \
# 1           2.0  15647311.0       Hill         608     Spain  Female  41.0
# 3           4.0  15701354.0       Boni         699    France  Female  39.0
# 5           6.0  15574012.0        Chu         645     Spain    Male  44.0
# 6           7.0  15592531.0   Bartlett         822    France    Male  50.0
# 7           8.0  15656148.0     Obinna         376   Germany  Female  29.0
# ...         ...         ...        ...         ...       ...     ...   ...
# 11938    7848.0  15769915.0   Charlton         643     Spain  Female  20.0
# 11983    1316.0  15734634.0  Bocharova         607     Spain  Female  27.0
# 11991    7229.0  15707602.0    Macleod         539    France  Female  47.0
# 12088    9435.0  15733229.0  Rodriguez         638     Spain  Female  34.0
# 12167    9945.0  15703923.0    Cameron         744   Germany    Male  41.0
#
#       Tenure    Balance  NumOfProducts HasCrCard IsActiveMember  \
# ...

# %%
df_without_nulls_and_duplicates.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Tabla booleana para ver si la columna Surname es igual a Hargrave
df['Surname']=='Hargrave'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12200    False
# 12201    False
# 12202    False
# 12203    False
# 12204    False
# Name: Surname, Length: 12205, dtype: bool

# %%
#Busca solo a los que son de alemania
df[df['Geography']=='Germany']
# Out:
#       RowNumber  CustomerId     Surname CreditScore Geography  Gender  \
# 7           8.0  15656148.0      Obinna         376   Germany  Female
# 16         17.0  15737452.0       Romeo         653   Germany    Male
# 26         27.0  15736816.0       Young         756   Germany    Male
# 28         29.0  15728693.0  McWilliams         574   Germany  Female
# 32         33.0  15750181.0   Sanderson         553   Germany    Male
# ...         ...         ...         ...         ...       ...     ...
# 12179    5893.0  15669219.0      Wilson         588   Germany    Male
# 12185     254.0  15694717.0          Ku         544   Germany    Male
# 12187    6708.0  15735909.0    McDonald         607   Germany  Female
# 12193    1076.0  15762937.0     Chiganu         743   Germany  Female
# 12203    8299.0  15605534.0    Turnbull         644   Germany  Female
#
#                  Age Tenure        Balance  NumOfProducts HasCrCard  \
# ...

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany', 'invalid_value', nan], dtype=object)

# %%
France=df[df['Geography']=='France']
France
# Out:
#       RowNumber  CustomerId   Surname CreditScore Geography  Gender   Age  \
# 0           1.0  15634602.0  Hargrave         619    France  Female   NaN
# 2           3.0  15619304.0      Onio         502    France  Female  42.0
# 3           4.0  15701354.0      Boni         699    France  Female  39.0
# 6           7.0  15592531.0  Bartlett         822    France    Male  50.0
# 8           9.0  15792365.0        He         501    France    Male  44.0
# ...         ...         ...       ...         ...       ...     ...   ...
# 12197    2705.0  15622494.0  Mazzanti         718    France    Male  27.0
# 12198    6261.0  15672826.0      Chen         666    France  Female  32.0
# 12199    2271.0  15622217.0        Tu         538    France  Female  38.0
# 12201    1272.0  15793854.0     Ahmed         723    France    Male  42.0
# 12204    1689.0  15804610.0    Valdez         601    France  Female  41.0
#
#       Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %%
Germany=df[df['Geography']=='Germany']
Germany
# Out:
#       RowNumber  CustomerId     Surname CreditScore Geography  Gender  \
# 7           8.0  15656148.0      Obinna         376   Germany  Female
# 16         17.0  15737452.0       Romeo         653   Germany    Male
# 26         27.0  15736816.0       Young         756   Germany    Male
# 28         29.0  15728693.0  McWilliams         574   Germany  Female
# 32         33.0  15750181.0   Sanderson         553   Germany    Male
# ...         ...         ...         ...         ...       ...     ...
# 12179    5893.0  15669219.0      Wilson         588   Germany    Male
# 12185     254.0  15694717.0          Ku         544   Germany    Male
# 12187    6708.0  15735909.0    McDonald         607   Germany  Female
# 12193    1076.0  15762937.0     Chiganu         743   Germany  Female
# 12203    8299.0  15605534.0    Turnbull         644   Germany  Female
#
#                  Age Tenure        Balance  NumOfProducts HasCrCard  \
# ...

# %%
Spain=df[df['Geography']=='Spain']
Spain
# Out:
#       RowNumber  CustomerId   Surname CreditScore Geography  Gender   Age  \
# 1           2.0  15647311.0      Hill         608     Spain  Female  41.0
# 4           5.0  15737888.0  Mitchell         850     Spain  Female   NaN
# 5           6.0  15574012.0       Chu         645     Spain    Male  44.0
# 11         12.0  15737173.0   Andrews         497     Spain    Male  24.0
# 14         15.0  15600882.0       NaN         635     Spain  Female  35.0
# ...         ...         ...       ...         ...       ...     ...   ...
# 12172    5110.0  15576156.0     Abazu         710     Spain  Female  28.0
# 12173    8452.0  15580043.0    Murray         575     Spain  Female  22.0
# 12181    9503.0  15686743.0     Moody         790     Spain    Male  29.0
# 12192    6535.0  15590078.0     Burns         622     Spain    Male  27.0
# 12200    7026.0  15711446.0  Sinclair         569     Spain  Female  51.0
#
#       Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %%
InvalidValue=df[df['Geography']=='invalid_value']
InvalidValue
# Out:
#       RowNumber  CustomerId     Surname CreditScore      Geography  Gender  \
# 9          10.0  15592389.0          H?         684  invalid_value    Male
# 18         19.0  15661507.0     Muldrow         587  invalid_value    Male
# 79         80.0  15803136.0      Postle         416  invalid_value  Female
# 178       179.0  15762615.0    Campbell         597  invalid_value  Female
# 370       371.0  15611579.0  Sutherland         801  invalid_value    Male
# ...         ...         ...         ...         ...            ...     ...
# 11657    4981.0  15740406.0    Padovesi         628  invalid_value    Male
# 11992    6151.0  15625761.0     Maclean         632  invalid_value    Male
# 12174    1562.0  15766374.0        Leak         632  invalid_value     NaN
# 12184    9745.0  15785358.0   Gresswell         586  invalid_value    Male
# 12202    4942.0  15715047.0      Joshua         640  invalid_value    Male
#
# ...

# %%
#Buscar cuantos texto especifico en una columna
df[df['CustomerId']== 'invalid_value'].shape[0]
# Out:
# 140

# %%
#Cuenta los datos invalidos en todas las columnas
contador = {}

for col in df.columns:
    contador[col] = df[df[col]== 'invalid_value'].shape[0]
contador
# Out:
# {'RowNumber': 134,
#  'CustomerId': 140,
#  'Surname': 123,
#  'CreditScore': 119,
#  'Geography': 139,
#  'Gender': 116,
#  'Age': 114,
#  'Tenure': 148,
#  'Balance': 163,
#  'NumOfProducts': 158,
#  'HasCrCard': 129,
#  'IsActiveMember': 135,
#  'EstimatedSalary': 157,
#  'Exited': 139,
#  'Complain': 165,
#  'Satisfaction Score': 161,
#  'Card Type': 137,
#  'Point Earned': 142}

# %%
#Valor diferente a invalid value
df[df['Geography']!='invalid_value']
# Out:
#       RowNumber  CustomerId   Surname CreditScore Geography  Gender   Age  \
# 0           1.0  15634602.0  Hargrave         619    France  Female   NaN
# 1           2.0  15647311.0      Hill         608     Spain  Female  41.0
# 2           3.0  15619304.0      Onio         502    France  Female  42.0
# 3           4.0  15701354.0      Boni         699    France  Female  39.0
# 4           5.0  15737888.0  Mitchell         850     Spain  Female   NaN
# ...         ...         ...       ...         ...       ...     ...   ...
# 12199    2271.0  15622217.0        Tu         538    France  Female  38.0
# 12200    7026.0  15711446.0  Sinclair         569     Spain  Female  51.0
# 12201    1272.0  15793854.0     Ahmed         723    France    Male  42.0
# 12203    8299.0  15605534.0  Turnbull         644   Germany  Female  51.0
# 12204    1689.0  15804610.0    Valdez         601    France  Female  41.0
#
#       Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %%
df_filtrado = df
for col in df.columns:
    df_filtrado = df_filtrado[df_filtrado[col] != 'invalid_value']
df_filtrado
# Out:
#       RowNumber  CustomerId   Surname CreditScore Geography  Gender   Age  \
# 0           1.0  15634602.0  Hargrave         619    France  Female   NaN
# 1           2.0  15647311.0      Hill         608     Spain  Female  41.0
# 2           3.0  15619304.0      Onio         502    France  Female  42.0
# 5           6.0  15574012.0       Chu         645     Spain    Male  44.0
# 6           7.0  15592531.0  Bartlett         822    France    Male  50.0
# ...         ...         ...       ...         ...       ...     ...   ...
# 12199    2271.0  15622217.0        Tu         538    France  Female  38.0
# 12200    7026.0  15711446.0  Sinclair         569     Spain  Female  51.0
# 12201    1272.0  15793854.0     Ahmed         723    France    Male  42.0
# 12203    8299.0  15605534.0  Turnbull         644   Germany  Female  51.0
# 12204    1689.0  15804610.0    Valdez         601    France  Female  41.0
#
#       Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %%
#Cuenta los datos invalidos en todas las columnas
contador = {}

for col in df_filtrado.columns:
    contador[col] = df_filtrado[df_filtrado[col]== 'invalid_value'].shape[0]

contador
# Out:
# {'RowNumber': 0,
#  'CustomerId': 0,
#  'Surname': 0,
#  'CreditScore': 0,
#  'Geography': 0,
#  'Gender': 0,
#  'Age': 0,
#  'Tenure': 0,
#  'Balance': 0,
#  'NumOfProducts': 0,
#  'HasCrCard': 0,
#  'IsActiveMember': 0,
#  'EstimatedSalary': 0,
#  'Exited': 0,
#  'Complain': 0,
#  'Satisfaction Score': 0,
#  'Card Type': 0,
#  'Point Earned': 0}

# %%
df_filtrado=df_filtrado.dropna()
df_filtrado.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %%
df_filtrado.shape
# Out:
# (8103, 18)

# %%
df_filtrado['IsActiveMember']=df_filtrado['IsActiveMember'].astype(int)

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8103 entries, 1 to 12204
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           8103 non-null   object
#  1   CustomerId          8103 non-null   int64
#  2   Surname             8103 non-null   object
#  3   CreditScore         8103 non-null   int64
#  4   Geography           8103 non-null   object
#  5   Gender              8103 non-null   object
#  6   Age                 8103 non-null   int64
#  7   Tenure              8103 non-null   object
#  8   Balance             8103 non-null   object
#  9   NumOfProducts       8103 non-null   object
#  10  HasCrCard           8103 non-null   object
#  11  IsActiveMember      8103 non-null   int64
#  12  EstimatedSalary     8103 non-null   object
#  13  Exited              8103 non-null   object
#  14  Complain            8103 non-null   object
# ...

# %%
df_filtrado['CustomerId']=df_filtrado['CustomerId'].astype(int)

# %%
df_filtrado['Age']=df_filtrado['Age'].astype(int)

# %%
df_filtrado['CreditScore']=df_filtrado['CreditScore'].astype(int)

# %%
df_filtrado.head()
# Out:
#   RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age Tenure  \
# 1       2.0    15647311      Hill          608     Spain  Female   41      1
# 5       6.0    15574012       Chu          645     Spain    Male   44      8
# 6       7.0    15592531  Bartlett          822    France    Male   50      7
# 7       8.0    15656148    Obinna          376   Germany  Female   29      4
# 8       9.0    15792365        He          501    France    Male   44      4
#
#      Balance NumOfProducts HasCrCard  IsActiveMember EstimatedSalary Exited  \
# 1   83807.86           1.0         0               1       112542.58      0
# 5  113755.78           2.0         1               0       149756.71      1
# 6        0.0           2.0         1               1         10062.8      0
# 7  115046.74           4.0         1               0       119346.88      1
# 8  142051.07           2.0         0               1         74940.5      0
#
# ...

# %%
df_filtrado['Tenure']=df_filtrado['Tenure'].astype(int)

# %%
df_filtrado['Balance']=df_filtrado['Balance'].astype(float)

# %%
df_filtrado['NumOfProducts']=df_filtrado['NumOfProducts'].astype(int)

# %%
df_filtrado['HasCrCard']=df_filtrado['HasCrCard'].astype(int)

# %%
df_filtrado['RowNumber']=df_filtrado['RowNumber'].astype(int)

# %%
df_filtrado['EstimatedSalary']=df_filtrado['EstimatedSalary'].astype(float)

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8103 entries, 1 to 12204
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           8103 non-null   object
#  1   CustomerId          8103 non-null   int64
#  2   Surname             8103 non-null   object
#  3   CreditScore         8103 non-null   int64
#  4   Geography           8103 non-null   object
#  5   Gender              8103 non-null   object
#  6   Age                 8103 non-null   int64
#  7   Tenure              8103 non-null   int64
#  8   Balance             8103 non-null   float64
#  9   NumOfProducts       8103 non-null   int64
#  10  HasCrCard           8103 non-null   int64
#  11  IsActiveMember      8103 non-null   int64
#  12  EstimatedSalary     8103 non-null   float64
#  13  Exited              8103 non-null   int64
#  14  Complain            8103 non-null   int64
#  15  Satisfaction Score  8103 non-null   int64
# ...

# %%
df_filtrado['Exited']=df_filtrado['Exited'].astype(int)

# %%
df_filtrado['Complain']=df_filtrado['Complain'].astype(int)

# %%
df_filtrado['Satisfaction Score']=df_filtrado['Satisfaction Score'].astype(int)

# %%
df_filtrado['Point Earned']=df_filtrado['Point Earned'].astype(int)
